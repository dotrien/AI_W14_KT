# %% [markdown]
# <a href="https://colab.research.google.com/github/dotrien/AI_W14_KT/blob/main/W13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 5.0 MB/s
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
# Lấy tên file ảnh
filename="hinh1.jpg"
pixel=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(pixel)
for face in faces:
  print(face)
# Out:
# {'box': [269, 281, 28, 35], 'confidence': 0.9999852180480957, 'keypoints': {'left_eye': (279, 294), 'right_eye': (292, 294), 'nose': (287, 300), 'mouth_left': (280, 307), 'mouth_right': (291, 308)}}
# {'box': [179, 285, 27, 39], 'confidence': 0.9999630451202393, 'keypoints': {'left_eye': (196, 300), 'right_eye': (206, 302), 'nose': (204, 309), 'mouth_left': (192, 314), 'mouth_right': (202, 316)}}
# {'box': [432, 284, 28, 32], 'confidence': 0.9971662163734436, 'keypoints': {'left_eye': (437, 298), 'right_eye': (450, 295), 'nose': (444, 303), 'mouth_left': (440, 310), 'mouth_right': (451, 308)}}
# {'box': [352, 323, 23, 26], 'confidence': 0.9878906011581421, 'keypoints': {'left_eye': (359, 333), 'right_eye': (369, 331), 'nose': (366, 337), 'mouth_left': (364, 344), 'mouth_right': (371, 343)}}

# %%
# Lấy tên file ảnh
filename="hinh1.jpg"
pixel=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(pixel)
data=plt.imread(filename)
plt.imshow(data)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  re=plt.Rectangle((x,y), width, height, fill=False, color='red')
  ax.add_patch(re)
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
plt.show()

# %%
def draw_faces(filename,result_list):
  data=plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height=result_list[i]['box']
    x2,y2=x1+width,y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()

# %%
filename="hinh1.jpg"
pixel=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(pixel)
draw_faces(filename,faces)

# %%
# Bài tập sử dụng toàn bộ CNN
# 1. Phân loại các món ăn VN (10 món)
# 2. Trái cây nhiệt đới (10 loại )
# 3. Nhận dạng tiền giấy
# 4. Xem chỉ tay
